# %% [markdown]
# <a href="https://colab.research.google.com/github/techpvk/techpvk/blob/master/Session4_Batch5_VenkataKumar_P_DNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# List and Clear the Data first
# !ls
# !rm -rf sample_data tiny-imagenet-200	tiny-imagenet-200.zip
# list content after the clearing data
# !ls
# Download the file
# !wget http://cs231n.stanford.edu/tiny-imagenet-200.zip
  #unzip and list
# !unzip -qq 'tiny-imagenet-200.zip'
# !ls
filepath="drive/app/weights.best.hdf5"
# Out:
# --2019-04-02 07:13:49--  http://cs231n.stanford.edu/tiny-imagenet-200.zip
# Resolving cs231n.stanford.edu (cs231n.stanford.edu)... 171.64.68.10
# Connecting to cs231n.stanford.edu (cs231n.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 248100043 (237M) [application/zip]
# Saving to: ‘tiny-imagenet-200.zip’
#
# tiny-imagenet-200.z 100%[===================>] 236.61M  37.0MB/s    in 7.6s
#
# 2019-04-02 07:13:57 (31.3 MB/s) - ‘tiny-imagenet-200.zip’ saved [248100043/248100043]
#
# tiny-imagenet-200  tiny-imagenet-200.zip

# %%
# !apt-get install -y -qq software-properties-common python-software-properties module-init-tools
# !add-apt-repository -y ppa:alessandro-strada/ppa 2>&1 > /dev/null
# !apt-get update -qq 2>&1 > /dev/null
# !apt-get -y install -qq google-drive-ocamlfuse fuse
from google.colab import auth
auth.authenticate_user()
from oauth2client.client import GoogleCredentials
creds = GoogleCredentials.get_application_default()
import getpass
# !google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret} < /dev/null 2>&1 | grep URL
vcode = getpass.getpass()
# !echo {vcode} | google-drive-ocamlfuse -headless -id={creds.client_id} -secret={creds.client_secret}
# !mkdir -p drive
# !google-drive-ocamlfuse drive
# !ls drive
# Out:
# E: Package 'python-software-properties' has no installation candidate
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# ··········
# Please, open the following URL in a web browser: https://accounts.google.com/o/oauth2/auth?client_id=32555940559.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive&response_type=code&access_type=offline&approval_prompt=force
# Please enter the verification code: Access token retrieved correctly.
#  app		    Recording_1.mp3  'Untitled Diagram.html'
# 'Colab Notebooks'   Recording.mp3     venkatakumar-puvvada.docx
# 'Getting started'  'Session 3.zip'

# %%
# import the required packages
import pandas as pd
import numpy as np
import six
from keras.preprocessing.image import ImageDataGenerator
from __future__ import division
from keras.models import Model
from keras.layers import (
    Input,
    Activation,
    Dense,
    Flatten,
    Dropout,
    SeparableConv2D
)
from keras.layers.convolutional import (
    Conv2D,
    MaxPooling2D,
    AveragePooling2D
)
from keras.layers.merge import add
from keras.layers.normalization import BatchNormalization
from keras.regularizers import l2
from keras import backend as K
from __future__ import print_function
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils
from keras.callbacks import ReduceLROnPlateau, CSVLogger, EarlyStopping
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import os
import cv2
from keras.layers import GlobalAveragePooling2D
from keras.models import Model, load_model, model_from_yaml
from keras.utils.vis_utils import plot_model
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %%
def _bn_relu(input):
    """Helper to build a BN -> relu block
    """
    norm = BatchNormalization(axis=CHANNEL_AXIS)(input)
    return Activation("relu")(norm)


def _conv_bn_relu(**conv_params):
    """Helper to build a conv -> BN -> relu block
    """
    filters = conv_params["filters"]
    name = conv_params["name"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1.e-4))
    def f(input):
        conv = SeparableConv2D(filters=filters, kernel_size=kernel_size,
                      strides=strides, padding=padding,
                      kernel_initializer=kernel_initializer,
                      kernel_regularizer=kernel_regularizer,
                     name=name)(input)
        return _bn_relu(conv)

    return f


def _bn_relu_conv(**conv_params):
    """Helper to build a BN -> relu -> conv block.
    This is an improved scheme proposed in http://arxiv.org/pdf/1603.05027v2.pdf
    """
    filters = conv_params["filters"]
    kernel_size = conv_params["kernel_size"]
    strides = conv_params.setdefault("strides", (1, 1))
    kernel_initializer = conv_params.setdefault("kernel_initializer", "he_normal")
    padding = conv_params.setdefault("padding", "same")
    kernel_regularizer = conv_params.setdefault("kernel_regularizer", l2(1.e-4))
    def f(input):
        activation = _bn_relu(input)
        return SeparableConv2D(filters=filters, kernel_size=kernel_size,
                      strides=strides, padding=padding,
                      kernel_initializer=kernel_initializer,
                      kernel_regularizer=kernel_regularizer)(activation)

    return f


def _shortcut(input, residual):
    """Adds a shortcut between input and residual block and merges them with "sum"
    """
    # Expand channels of shortcut to match residual.
    # Stride appropriately to match residual (width, height)
    # Should be int if network architecture is correctly configured.
    input_shape = K.int_shape(input)
    residual_shape = K.int_shape(residual)
    stride_width = int(round(input_shape[ROW_AXIS] / residual_shape[ROW_AXIS]))
    stride_height = int(round(input_shape[COL_AXIS] / residual_shape[COL_AXIS]))
    equal_channels = input_shape[CHANNEL_AXIS] == residual_shape[CHANNEL_AXIS]

    shortcut = input
    # 1 X 1 conv if shape is different. Else identity.
    if stride_width > 1 or stride_height > 1 or not equal_channels:
        shortcut = SeparableConv2D(filters=residual_shape[CHANNEL_AXIS],
                          kernel_size=(1, 1),
                          strides=(stride_width, stride_height),
                          padding="valid",
                          kernel_initializer="he_normal",
                          kernel_regularizer=l2(0.0001))(input)
    return add([shortcut, residual])


def _residual_block(block_function, filters, repetitions, is_first_layer=False):
    """Builds a residual block with repeating bottleneck blocks.
    """
    def f(input):
        
        for i in range(repetitions):
            init_strides = (1, 1)
            if i == 0 and not is_first_layer:
                init_strides = (2, 2)
            input = block_function(filters=filters, init_strides=init_strides,
                                   is_first_block_of_first_layer=(is_first_layer and i == 0))(input)
        return input

    return f


def basic_block(filters, init_strides=(1, 1), is_first_block_of_first_layer=False):
    """Basic 3 X 3 convolution blocks for use on resnets with layers <= 34.
    Follows improved proposed scheme in http://arxiv.org/pdf/1603.05027v2.pdf
    """
    def f(input):

        if is_first_block_of_first_layer:
            # don't repeat bn->relu since we just did bn->relu->maxpool
            conv1 = Conv2D(filters=filters, kernel_size=(3, 3),
                           strides=init_strides,
                           padding="same",
                           kernel_initializer="he_normal",
                           kernel_regularizer=l2(1e-4))(input)
        else:
            conv1 = _bn_relu_conv(filters=filters, kernel_size=(3, 3),
                                  strides=init_strides)(input)

        residual = _bn_relu_conv(filters=filters, kernel_size=(3, 3))(conv1)
        return _shortcut(input, residual)

    return f


def bottleneck(filters, init_strides=(1, 1), is_first_block_of_first_layer=False):
    """Bottleneck architecture for > 34 layer resnet.
    Follows improved proposed scheme in http://arxiv.org/pdf/1603.05027v2.pdf
    Returns:
        A final conv layer of filters * 4
    """
    def f(input):
        if is_first_block_of_first_layer:
            # don't repeat bn->relu since we just did bn->relu->maxpool
            conv_1_1 = Conv2D(filters=filters, kernel_size=(1, 1),
                              strides=init_strides,
                              padding="same",
                              kernel_initializer="he_normal",
                              kernel_regularizer=l2(1e-4))(input)
        else:
            conv_1_1 = _bn_relu_conv(filters=filters, kernel_size=(1, 1),
                                     strides=init_strides)(input)

        conv_3_3 = _bn_relu_conv(filters=filters, kernel_size=(3, 3))(conv_1_1)
        residual = _bn_relu_conv(filters=filters * 4, kernel_size=(1, 1))(conv_3_3)
        return _shortcut(input, residual)

    return f

def bottleneck_pyramid(filters, init_strides=(1, 1), is_first_block_of_first_layer=False):
    """Bottleneck architecture for > 34 layer resnet.
    Follows improved proposed scheme in http://arxiv.org/pdf/1603.05027v2.pdf
    Returns:
        A final conv layer of filters * 4
    """
    def f(input):
        if is_first_block_of_first_layer:
            # don't repeat bn->relu since we just did bn->relu->maxpool
            conv_1_1 = SeparableConv2D(filters=filters, kernel_size=(1, 1),
                              strides=init_strides,
                              padding="same",
                              kernel_initializer="he_normal",
                              kernel_regularizer=l2(1e-4))(input)
        else:
            conv_1_1 = _bn_relu_conv(filters=filters, kernel_size=(1, 1),
                                     strides=(1,1))(input)

        conv_3_3_1 = _bn_relu_conv(filters=filters * 2, kernel_size=(3, 3))(conv_1_1)
        conv_3_3_2 = _bn_relu_conv(filters=filters * 4, kernel_size=(3, 3))(conv_3_3_1)
        conv_3_3_3 = _bn_relu_conv(filters=filters * 8, kernel_size=(3, 3))(conv_3_3_2)
        if is_first_block_of_first_layer:
           return _shortcut(input, conv_3_3_3)
        else:
            conv_3_3_3 = _bn_relu(conv_3_3_3)
            conv_max_pool = MaxPooling2D(pool_size=(2, 2))(conv_3_3_3)
            residual = _bn_relu(conv_max_pool)
            #residual = _bn_relu_conv(filters=filters * 8, kernel_size=(3, 3))(conv_3_3_2)
            return _shortcut(input, residual)
          
    return f


def _handle_dim_ordering():
    global ROW_AXIS
    global COL_AXIS
    global CHANNEL_AXIS
    if K.image_dim_ordering() == 'tf':
        ROW_AXIS = 1
        COL_AXIS = 2
        CHANNEL_AXIS = 3
    else:
        CHANNEL_AXIS = 1
        ROW_AXIS = 2
        COL_AXIS = 3


def _get_block(identifier):
    if isinstance(identifier, six.string_types):
        res = globals().get(identifier)
        if not res:
            raise ValueError('Invalid {}'.format(identifier))
        return res
    return identifier


class ResnetBuilder(object):
    @staticmethod
    def build(input_shape, num_outputs, block_fn, repetitions):
        """Builds a custom ResNet like architecture.
        Args:
            input_shape: The input shape in the form (nb_channels, nb_rows, nb_cols)
            num_outputs: The number of outputs at final softmax layer
            block_fn: The block function to use. This is either `basic_block` or `bottleneck`.
                The original paper used basic_block for layers < 50
            repetitions: Number of repetitions of various block units.
                At each block unit, the number of filters are doubled and the input size is halved
        Returns:
            The keras `Model`.
        """
        _handle_dim_ordering()
        if len(input_shape) != 3:
            raise Exception("Input shape should be a tuple (nb_channels, nb_rows, nb_cols)")

        # Permute dimension order if necessary
        if K.image_dim_ordering() == 'tf':
            input_shape = (input_shape[1], input_shape[2], input_shape[0])
        # Load function from str if needed.
        block_fn = _get_block(block_fn)
        input = Input(shape=input_shape)
        conv1 = _conv_bn_relu(filters=64, kernel_size=(3, 3), strides=(1, 1),name='init-2d')(input)
        #pool1 = MaxPooling2D(pool_size=(3, 3), strides=(2, 2), padding="same")(conv1)
        #x = Dropout(0.5)(pool1)
        #block = conv1
        block = input
        filters = 32
        for i, r in enumerate(repetitions):
            block = _residual_block(block_fn, filters=filters, repetitions=r, is_first_layer=(i == 0))(block)
            filters *= 2

        # Last activation
        block = _bn_relu(block)

        # Classifier block
        #block_shape = K.int_shape(block)
        #pool2 = AveragePooling2D(pool_size=(block_shape[ROW_AXIS], block_shape[COL_AXIS]),
        #                         strides=(1, 1))(block)
        #flatten1 = Flatten()(pool2)
        #x = Dropout(0.5)(flatten1)
        #dense = Dense(units=num_outputs, kernel_initializer="he_normal",
        #              activation="softmax")(x)
        x = Conv2D(200, (1,1), strides=(1,1), padding='same', name='final2d', use_bias=False)(block)
        x = _bn_relu(x)
        x = GlobalAveragePooling2D(data_format='channels_last')(x)
        # out = Flatten()(x)
        out = Activation('softmax') (x)
        model = Model(inputs=input, outputs=out)
        return model

    @staticmethod
    def build_resnet_18(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, basic_block, [2, 2, 2, 2])

    @staticmethod
    def build_resnet_34(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, basic_block, [3, 4, 6, 3])

    @staticmethod
    def build_resnet_50(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, bottleneck, [3, 4, 6, 3])
      
    @staticmethod
    def build_resnet_50_pyramid(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, bottleneck_pyramid, [1, 1, 1, 1])

    @staticmethod
    def build_resnet_101(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, bottleneck, [3, 4, 23, 3])

    @staticmethod
    def build_resnet_152(input_shape, num_outputs):
        return ResnetBuilder.build(input_shape, num_outputs, bottleneck, [3, 8, 36, 3])

# %%
# load data
val_data = pd.read_csv('./tiny-imagenet-200/val/val_annotations.txt', sep='\t', header=None, names=['File', 'Class', 'X', 'Y', 'H', 'W'])
val_data.drop(['X', 'Y', 'H', 'W'], axis=1, inplace=True)
#val_data.head(10)
# Use Augmentaion parameters as required.
train_datagen = ImageDataGenerator(
    rescale= 1./255,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True
    )

valid_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory( r'./tiny-imagenet-200/train/', target_size=(32, 32), color_mode='rgb', 
                                                    batch_size=200, class_mode='categorical', shuffle=True, seed=42)
validation_generator = valid_datagen.flow_from_dataframe(val_data, directory='./tiny-imagenet-200/val/images/', x_col='File', y_col='Class', target_size=(32, 32),
                                                    color_mode='rgb', class_mode='categorical', batch_size=200, shuffle=True, seed=42)
x_batch, y_batch = next(train_generator)
x_batch.shape
# Plot Generator images.  ** Re-run the cell to view different set of images.

fig = plt.figure(figsize=(14, 5))

for i in range(8):
    sub = fig.add_subplot(2, 4, i + 1)
    sub.imshow(x_batch[i,:,:], interpolation='nearest')
# Out:
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.

# %%
nb_classes = 200
#nb_epoch = 100
# input image dimensions
img_rows, img_cols = 32, 32
img_channels = 3
model = ResnetBuilder.build_resnet_50_pyramid((img_channels,img_rows,img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
plot_model(model, to_file='./tiny-imagenet-200/model_plot.png', show_shapes=True, show_layer_names=True)
from google.colab import files

files.download('./tiny-imagenet-200/model_plot.png')

# %%
model.summary()
#model.fit_generator(train_generator, epochs=nb_epoch, steps_per_epoch=200, validation_steps=200, validation_data=validation_generator
##steps_per_epoch=Integer. Total number of steps (batches of samples) to yield from generator before declaring one epoch finished and starting the next epoch. 
#It should typically be equal to ceil(num_samples / batch_size) Optional for Sequence: if unspecified, will use the len(generator) as a number of steps.
##validation_steps=Only relevant if validation_data is a generator. Total number of steps (batches of samples) to yield from validation_data generator before stopping at the end of every epoch. 
#It should typically be equal to the number of samples of your validation dataset divided by the batch size. Optional for Sequence: if unspecified, will use the len(validation_data) as a number of steps.
##epochs: Integer. Number of epochs to train the model. An epoch is an iteration over the entire data provided, as defined by steps_per_epoch. 
#Note that in conjunction with initial_epoch, epochs is to be understood as "final epoch". The model is not trained for a number of iterations given by epochs,
#but merely until the epoch of index epochs is reached.
#steps_per_epoch=100000/200=500
#validation_steps=10000/200=50
#nb_epoch = 100
# checkpoint
#filepath="./tiny-imagenet-200/weights.best.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

nb_epoch = 20
model.fit_generator(train_generator, epochs=nb_epoch, steps_per_epoch=500, validation_steps=50, validation_data=validation_generator, callbacks=callbacks_list)
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            (None, 32, 32, 3)    0
# __________________________________________________________________________________________________
# separable_conv2d_21 (SeparableC (None, 32, 32, 32)   131         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_26 (BatchNo (None, 32, 32, 32)   128         separable_conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 32, 32, 32)   0           batch_normalization_26[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_22 (SeparableC (None, 32, 32, 64)   2400        activation_27[0][0]
# __________________________________________________________________________________________________
# batch_normalization_27 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 32, 32, 64)   0           batch_normalization_27[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_23 (SeparableC (None, 32, 32, 128)  8896        activation_28[0][0]
# __________________________________________________________________________________________________
# batch_normalization_28 (BatchNo (None, 32, 32, 128)  512         separable_conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 32, 32, 128)  0           batch_normalization_28[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_25 (SeparableC (None, 32, 32, 256)  1027        input_2[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_24 (SeparableC (None, 32, 32, 256)  34176       activation_29[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 32, 32, 256)  0           separable_conv2d_25[0][0]
#                                                                  separable_conv2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_29 (BatchNo (None, 32, 32, 256)  1024        add_5[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 32, 32, 256)  0           batch_normalization_29[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_26 (SeparableC (None, 32, 32, 64)   16704       activation_30[0][0]
# __________________________________________________________________________________________________
# batch_normalization_30 (BatchNo (None, 32, 32, 64)   256         separable_conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 32, 32, 64)   0           batch_normalization_30[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_27 (SeparableC (None, 32, 32, 128)  8896        activation_31[0][0]
# __________________________________________________________________________________________________
# batch_normalization_31 (BatchNo (None, 32, 32, 128)  512         separable_conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 128)  0           batch_normalization_31[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_28 (SeparableC (None, 32, 32, 256)  34176       activation_32[0][0]
# __________________________________________________________________________________________________
# batch_normalization_32 (BatchNo (None, 32, 32, 256)  1024        separable_conv2d_28[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 32, 32, 256)  0           batch_normalization_32[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_29 (SeparableC (None, 32, 32, 512)  133888      activation_33[0][0]
# __________________________________________________________________________________________________
# batch_normalization_33 (BatchNo (None, 32, 32, 512)  2048        separable_conv2d_29[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 32, 32, 512)  0           batch_normalization_33[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_34[0][0]
# __________________________________________________________________________________________________
# batch_normalization_34 (BatchNo (None, 16, 16, 512)  2048        max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_30 (SeparableC (None, 16, 16, 512)  131840      add_5[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 16, 16, 512)  0           batch_normalization_34[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 16, 16, 512)  0           separable_conv2d_30[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# batch_normalization_35 (BatchNo (None, 16, 16, 512)  2048        add_6[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 16, 16, 512)  0           batch_normalization_35[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_31 (SeparableC (None, 16, 16, 128)  66176       activation_36[0][0]
# __________________________________________________________________________________________________
# batch_normalization_36 (BatchNo (None, 16, 16, 128)  512         separable_conv2d_31[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 16, 16, 128)  0           batch_normalization_36[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_32 (SeparableC (None, 16, 16, 256)  34176       activation_37[0][0]
# __________________________________________________________________________________________________
# batch_normalization_37 (BatchNo (None, 16, 16, 256)  1024        separable_conv2d_32[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 16, 16, 256)  0           batch_normalization_37[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_33 (SeparableC (None, 16, 16, 512)  133888      activation_38[0][0]
# __________________________________________________________________________________________________
# batch_normalization_38 (BatchNo (None, 16, 16, 512)  2048        separable_conv2d_33[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 16, 16, 512)  0           batch_normalization_38[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_34 (SeparableC (None, 16, 16, 1024) 529920      activation_39[0][0]
# __________________________________________________________________________________________________
# batch_normalization_39 (BatchNo (None, 16, 16, 1024) 4096        separable_conv2d_34[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 16, 16, 1024) 0           batch_normalization_39[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 8, 8, 1024)   0           activation_40[0][0]
# __________________________________________________________________________________________________
# batch_normalization_40 (BatchNo (None, 8, 8, 1024)   4096        max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_35 (SeparableC (None, 8, 8, 1024)   525824      add_6[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 8, 8, 1024)   0           batch_normalization_40[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 8, 8, 1024)   0           separable_conv2d_35[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# batch_normalization_41 (BatchNo (None, 8, 8, 1024)   4096        add_7[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 8, 8, 1024)   0           batch_normalization_41[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_36 (SeparableC (None, 8, 8, 256)    263424      activation_42[0][0]
# __________________________________________________________________________________________________
# batch_normalization_42 (BatchNo (None, 8, 8, 256)    1024        separable_conv2d_36[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 8, 8, 256)    0           batch_normalization_42[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_37 (SeparableC (None, 8, 8, 512)    133888      activation_43[0][0]
# __________________________________________________________________________________________________
# batch_normalization_43 (BatchNo (None, 8, 8, 512)    2048        separable_conv2d_37[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 8, 8, 512)    0           batch_normalization_43[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_38 (SeparableC (None, 8, 8, 1024)   529920      activation_44[0][0]
# __________________________________________________________________________________________________
# batch_normalization_44 (BatchNo (None, 8, 8, 1024)   4096        separable_conv2d_38[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 8, 8, 1024)   0           batch_normalization_44[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_39 (SeparableC (None, 8, 8, 2048)   2108416     activation_45[0][0]
# __________________________________________________________________________________________________
# batch_normalization_45 (BatchNo (None, 8, 8, 2048)   8192        separable_conv2d_39[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 8, 8, 2048)   0           batch_normalization_45[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 4, 4, 2048)   0           activation_46[0][0]
# __________________________________________________________________________________________________
# batch_normalization_46 (BatchNo (None, 4, 4, 2048)   8192        max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# separable_conv2d_40 (SeparableC (None, 4, 4, 2048)   2100224     add_7[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 4, 4, 2048)   0           batch_normalization_46[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 4, 4, 2048)   0           separable_conv2d_40[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# batch_normalization_47 (BatchNo (None, 4, 4, 2048)   8192        add_8[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 4, 4, 2048)   0           batch_normalization_47[0][0]
# __________________________________________________________________________________________________
# final2d (Conv2D)                (None, 4, 4, 200)    409600      activation_48[0][0]
# __________________________________________________________________________________________________
# batch_normalization_48 (BatchNo (None, 4, 4, 200)    800         final2d[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 4, 4, 200)    0           batch_normalization_48[0][0]
# __________________________________________________________________________________________________
# global_average_pooling2d_2 (Glo (None, 200)          0           activation_49[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 200)          0           global_average_pooling2d_2[0][0]
# ==================================================================================================
# Total params: 7,265,862
# Trainable params: 7,236,726
# Non-trainable params: 29,136
# __________________________________________________________________________________________________
# Epoch 1/20
# 500/500 [==============================] - 628s 1s/step - loss: 4.6416 - acc: 0.0781 - val_loss: 6.6590 - val_acc: 0.0579
#
# Epoch 00001: val_acc improved from -inf to 0.05790, saving model to drive/app/weights.best.hdf5
# Epoch 2/20
# 500/500 [==============================] - 617s 1s/step - loss: 3.9412 - acc: 0.1732 - val_loss: 5.1139 - val_acc: 0.0664
#
# Epoch 00002: val_acc improved from 0.05790 to 0.06640, saving model to drive/app/weights.best.hdf5
# Epoch 3/20
# 500/500 [==============================] - 617s 1s/step - loss: 3.5207 - acc: 0.2385 - val_loss: 3.8811 - val_acc: 0.1803
#
# Epoch 00003: val_acc improved from 0.06640 to 0.18030, saving model to drive/app/weights.best.hdf5
# Epoch 4/20
# 500/500 [==============================] - 619s 1s/step - loss: 3.2229 - acc: 0.2912 - val_loss: 3.7425 - val_acc: 0.2050
#
# Epoch 00004: val_acc improved from 0.18030 to 0.20500, saving model to drive/app/weights.best.hdf5
# Epoch 5/20
# 500/500 [==============================] - 617s 1s/step - loss: 2.9969 - acc: 0.3293 - val_loss: 3.3017 - val_acc: 0.2791
#
# Epoch 00005: val_acc improved from 0.20500 to 0.27910, saving model to drive/app/weights.best.hdf5
# Epoch 6/20
# 500/500 [==============================] - 619s 1s/step - loss: 2.8124 - acc: 0.3622 - val_loss: 3.0341 - val_acc: 0.3227
#
# Epoch 00006: val_acc improved from 0.27910 to 0.32270, saving model to drive/app/weights.best.hdf5
# Epoch 7/20
# 500/500 [==============================] - 618s 1s/step - loss: 2.6490 - acc: 0.3925 - val_loss: 3.6710 - val_acc: 0.2381
#
# Epoch 00007: val_acc did not improve from 0.32270
# Epoch 8/20
# 500/500 [==============================] - 619s 1s/step - loss: 2.5024 - acc: 0.4191 - val_loss: 3.6071 - val_acc: 0.2409
#
# Epoch 00008: val_acc did not improve from 0.32270
# Epoch 9/20
# 500/500 [==============================] - 619s 1s/step - loss: 2.3740 - acc: 0.4454 - val_loss: 2.9447 - val_acc: 0.3513
#
# Epoch 00009: val_acc improved from 0.32270 to 0.35130, saving model to drive/app/weights.best.hdf5
# Epoch 10/20
# 500/500 [==============================] - 620s 1s/step - loss: 2.2457 - acc: 0.4700 - val_loss: 2.8284 - val_acc: 0.3743
#
# Epoch 00010: val_acc improved from 0.35130 to 0.37430, saving model to drive/app/weights.best.hdf5
# Epoch 11/20
# 500/500 [==============================] - 618s 1s/step - loss: 2.1321 - acc: 0.4925 - val_loss: 2.8340 - val_acc: 0.3748
#
# Epoch 00011: val_acc improved from 0.37430 to 0.37480, saving model to drive/app/weights.best.hdf5
# Epoch 12/20
# 500/500 [==============================] - 619s 1s/step - loss: 2.0229 - acc: 0.5123 - val_loss: 2.6904 - val_acc: 0.4035
#
# Epoch 00012: val_acc improved from 0.37480 to 0.40350, saving model to drive/app/weights.best.hdf5
# Epoch 13/20
# 500/500 [==============================] - 618s 1s/step - loss: 1.9160 - acc: 0.5376 - val_loss: 3.1254 - val_acc: 0.3349
#
# Epoch 00013: val_acc did not improve from 0.40350
# Epoch 14/20
# 500/500 [==============================] - 619s 1s/step - loss: 1.8006 - acc: 0.5622 - val_loss: 2.8708 - val_acc: 0.3727
#
# Epoch 00014: val_acc did not improve from 0.40350
# Epoch 15/20
# 500/500 [==============================] - 619s 1s/step - loss: 1.6945 - acc: 0.5851 - val_loss: 2.7159 - val_acc: 0.4028
#
# Epoch 00015: val_acc did not improve from 0.40350
# Epoch 16/20
# 500/500 [==============================] - 619s 1s/step - loss: 1.5931 - acc: 0.6063 - val_loss: 2.6646 - val_acc: 0.4102
#
# Epoch 00016: val_acc improved from 0.40350 to 0.41020, saving model to drive/app/weights.best.hdf5
# Epoch 17/20
# 500/500 [==============================] - 619s 1s/step - loss: 1.4941 - acc: 0.6303 - val_loss: 2.6711 - val_acc: 0.4182
#
# Epoch 00017: val_acc improved from 0.41020 to 0.41820, saving model to drive/app/weights.best.hdf5
# Epoch 18/20
# 500/500 [==============================] - 619s 1s/step - loss: 1.3895 - acc: 0.6537 - val_loss: 2.8416 - val_acc: 0.3902
#
# Epoch 00018: val_acc did not improve from 0.41820
# Epoch 19/20
# 500/500 [==============================] - 620s 1s/step - loss: 1.2920 - acc: 0.6783 - val_loss: 2.8728 - val_acc: 0.4034
#
# Epoch 00019: val_acc did not improve from 0.41820
# Epoch 20/20
# 500/500 [==============================] - 619s 1s/step - loss: 1.2074 - acc: 0.6996 - val_loss: 2.7630 - val_acc: 0.4172
#
# Epoch 00020: val_acc did not improve from 0.41820

# %%
# load data
val_data = pd.read_csv('./tiny-imagenet-200/val/val_annotations.txt', sep='\t', header=None, names=['File', 'Class', 'X', 'Y', 'H', 'W'])
val_data.drop(['X', 'Y', 'H', 'W'], axis=1, inplace=True)
# input image dimensions
img_rows, img_cols = 16, 16
batch_size=400
#val_data.head(10)
# Use Augmentaion parameters as required.
train_datagen = ImageDataGenerator(
    rescale= 1./255,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True
    )

valid_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory( r'./tiny-imagenet-200/train/', target_size=(img_rows, img_cols), color_mode='rgb', 
                                                    batch_size=batch_size, class_mode='categorical', shuffle=True, seed=42)
validation_generator = valid_datagen.flow_from_dataframe(val_data, directory='./tiny-imagenet-200/val/images/', x_col='File', y_col='Class', target_size=(img_rows, img_cols),
                                                    color_mode='rgb', class_mode='categorical', batch_size=batch_size, shuffle=True, seed=42)
x_batch, y_batch = next(train_generator)
x_batch.shape
# Plot Generator images.  ** Re-run the cell to view different set of images.

fig = plt.figure(figsize=(14, 5))

for i in range(8):
    sub = fig.add_subplot(2, 4, i + 1)
    sub.imshow(x_batch[i,:,:], interpolation='nearest')
nb_classes = 200
#nb_epoch = 100
img_channels = 3
model = ResnetBuilder.build_resnet_50_pyramid((img_channels,img_rows,img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
#model.summary()

#model.fit_generator(train_generator, epochs=nb_epoch, steps_per_epoch=200, validation_steps=200, validation_data=validation_generator
##steps_per_epoch=Integer. Total number of steps (batches of samples) to yield from generator before declaring one epoch finished and starting the next epoch. 
#It should typically be equal to ceil(num_samples / batch_size) Optional for Sequence: if unspecified, will use the len(generator) as a number of steps.
##validation_steps=Only relevant if validation_data is a generator. Total number of steps (batches of samples) to yield from validation_data generator before stopping at the end of every epoch. 
#It should typically be equal to the number of samples of your validation dataset divided by the batch size. Optional for Sequence: if unspecified, will use the len(validation_data) as a number of steps.
##epochs: Integer. Number of epochs to train the model. An epoch is an iteration over the entire data provided, as defined by steps_per_epoch. 
#Note that in conjunction with initial_epoch, epochs is to be understood as "final epoch". The model is not trained for a number of iterations given by epochs,
#but merely until the epoch of index epochs is reached.
#steps_per_epoch=100000/200=500
#validation_steps=10000/200=50
#nb_epoch = 100
# checkpoint
#filepath="./tiny-imagenet-200/weights.best.hdf5"
model.load_weights(filepath)
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

nb_epoch = 5
model.fit_generator(train_generator, epochs=nb_epoch, steps_per_epoch=500, validation_steps=50, validation_data=validation_generator, callbacks=callbacks_list)
# Out:
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/5
# 500/500 [==============================] - 367s 733ms/step - loss: 2.6405 - acc: 0.3782 - val_loss: 3.4379 - val_acc: 0.3028
#
# Epoch 00001: val_acc improved from -inf to 0.30280, saving model to drive/app/weights.best.hdf5
# Epoch 2/5
# 500/500 [==============================] - 349s 698ms/step - loss: 2.1867 - acc: 0.4573 - val_loss: 3.3070 - val_acc: 0.3269
#
# Epoch 00002: val_acc improved from 0.30280 to 0.32690, saving model to drive/app/weights.best.hdf5
# Epoch 3/5
# 500/500 [==============================] - 350s 699ms/step - loss: 1.9405 - acc: 0.5075 - val_loss: 3.6121 - val_acc: 0.2974
#
# Epoch 00003: val_acc did not improve from 0.32690
# Epoch 4/5
# 500/500 [==============================] - 349s 698ms/step - loss: 1.7280 - acc: 0.5543 - val_loss: 3.4572 - val_acc: 0.3233
#
# Epoch 00004: val_acc did not improve from 0.32690
# Epoch 5/5
# 500/500 [==============================] - 350s 699ms/step - loss: 1.5405 - acc: 0.5996 - val_loss: 3.5206 - val_acc: 0.3204
#
# Epoch 00005: val_acc did not improve from 0.32690

# %%
# load data
val_data = pd.read_csv('./tiny-imagenet-200/val/val_annotations.txt', sep='\t', header=None, names=['File', 'Class', 'X', 'Y', 'H', 'W'])
val_data.drop(['X', 'Y', 'H', 'W'], axis=1, inplace=True)
# input image dimensions
img_rows, img_cols = 64, 64
batch_size=50
#val_data.head(10)
# Use Augmentaion parameters as required.
train_datagen = ImageDataGenerator(
    rescale= 1./255,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
    )

valid_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory( r'./tiny-imagenet-200/train/', target_size=(img_rows, img_cols), color_mode='rgb', 
                                                    batch_size=batch_size, class_mode='categorical', shuffle=True, seed=42)
validation_generator = valid_datagen.flow_from_dataframe(val_data, directory='./tiny-imagenet-200/val/images/', x_col='File', y_col='Class', target_size=(img_rows, img_cols),
                                                    color_mode='rgb', class_mode='categorical', batch_size=batch_size, shuffle=True, seed=42)
x_batch, y_batch = next(train_generator)
x_batch.shape
# Plot Generator images.  ** Re-run the cell to view different set of images.

fig = plt.figure(figsize=(14, 5))

for i in range(8):
    sub = fig.add_subplot(2, 4, i + 1)
    sub.imshow(x_batch[i,:,:], interpolation='nearest')
nb_classes = 200
#nb_epoch = 100
img_channels = 3
model = ResnetBuilder.build_resnet_50_pyramid((img_channels,img_rows,img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
#model.summary()

#model.fit_generator(train_generator, ep`ochs=nb_epoch, steps_per_epoch=200, validation_steps=200, validation_data=validation_generator
##steps_per_epoch=Integer. Total number of steps (batches of samples) to yield from generator before declaring one epoch finished and starting the next epoch. 
#It should typically be equal to ceil(num_samples / batch_size) Optional for Sequence: if unspecified, will use the len(generator) as a number of steps.
##validation_steps=Only relevant if validation_data is a generator. Total number of steps (batches of samples) to yield from validation_data generator before stopping at the end of every epoch. 
#It should typically be equal to the number of samples of your validation dataset divided by the batch size. Optional for Sequence: if unspecified, will use the len(validation_data) as a number of steps.
##epochs: Integer. Number of epochs to train the model. An epoch is an iteration over the entire data provided, as defined by steps_per_epoch. 
#Note that in conjunction with initial_epoch, epochs is to be understood as "final epoch". The model is not trained for a number of iterations given by epochs,
#but merely until the epoch of index epochs is reached.
#steps_per_epoch=100000/200=500
#validation_steps=10000/200=50
#nb_epoch = 100
# checkpoint
#filepath="./tiny-imagenet-200/weights.best.hdf5"
model.load_weights(filepath)
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

nb_epoch = 5
model.fit_generator(train_generator, epochs=nb_epoch, steps_per_epoch=500, validation_steps=50, validation_data=validation_generator, callbacks=callbacks_list)
# Out:
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/5
# 500/500 [==============================] - 792s 2s/step - loss: 2.6020 - acc: 0.4254 - val_loss: 2.7623 - val_acc: 0.3740
#
# Epoch 00001: val_acc improved from -inf to 0.37400, saving model to drive/app/weights.best.hdf5
# Epoch 2/5
# 500/500 [==============================] - 778s 2s/step - loss: 2.2293 - acc: 0.4896 - val_loss: 2.5799 - val_acc: 0.4068
#
# Epoch 00002: val_acc improved from 0.37400 to 0.40680, saving model to drive/app/weights.best.hdf5
# Epoch 3/5
# 500/500 [==============================] - 778s 2s/step - loss: 2.1094 - acc: 0.5102 - val_loss: 2.6377 - val_acc: 0.4004
#
# Epoch 00003: val_acc did not improve from 0.40680
# Epoch 4/5
# 500/500 [==============================] - 778s 2s/step - loss: 2.0614 - acc: 0.5220 - val_loss: 2.4735 - val_acc: 0.4404
#
# Epoch 00004: val_acc improved from 0.40680 to 0.44040, saving model to drive/app/weights.best.hdf5
# Epoch 5/5
# 500/500 [==============================] - 778s 2s/step - loss: 1.8076 - acc: 0.5795 - val_loss: 2.4926 - val_acc: 0.4300
#
# Epoch 00005: val_acc did not improve from 0.44040

# %%
# load data
val_data = pd.read_csv('./tiny-imagenet-200/val/val_annotations.txt', sep='\t', header=None, names=['File', 'Class', 'X', 'Y', 'H', 'W'])
val_data.drop(['X', 'Y', 'H', 'W'], axis=1, inplace=True)
# input image dimensions
img_rows, img_cols = 16, 16
batch_size=400
#val_data.head(10)
# Use Augmentaion parameters as required.
train_datagen = ImageDataGenerator(
    rescale= 1./255,
    width_shift_range=0.3,
    height_shift_range=0.3,
    horizontal_flip=True
    )

valid_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory( r'./tiny-imagenet-200/train/', target_size=(img_rows, img_cols), color_mode='rgb', 
                                                    batch_size=batch_size, class_mode='categorical', shuffle=True, seed=42)
validation_generator = valid_datagen.flow_from_dataframe(val_data, directory='./tiny-imagenet-200/val/images/', x_col='File', y_col='Class', target_size=(img_rows, img_cols),
                                                    color_mode='rgb', class_mode='categorical', batch_size=batch_size, shuffle=True, seed=42)
x_batch, y_batch = next(train_generator)
x_batch.shape
# Plot Generator images.  ** Re-run the cell to view different set of images.

fig = plt.figure(figsize=(14, 5))

for i in range(8):
    sub = fig.add_subplot(2, 4, i + 1)
    sub.imshow(x_batch[i,:,:], interpolation='nearest')
nb_classes = 200
#nb_epoch = 100
img_channels = 3
model = ResnetBuilder.build_resnet_50_pyramid((img_channels,img_rows,img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
#model.summary()

#model.fit_generator(train_generator, epochs=nb_epoch, steps_per_epoch=200, validation_steps=200, validation_data=validation_generator
##steps_per_epoch=Integer. Total number of steps (batches of samples) to yield from generator before declaring one epoch finished and starting the next epoch. 
#It should typically be equal to ceil(num_samples / batch_size) Optional for Sequence: if unspecified, will use the len(generator) as a number of steps.
##validation_steps=Only relevant if validation_data is a generator. Total number of steps (batches of samples) to yield from validation_data generator before stopping at the end of every epoch. 
#It should typically be equal to the number of samples of your validation dataset divided by the batch size. Optional for Sequence: if unspecified, will use the len(validation_data) as a number of steps.
##epochs: Integer. Number of epochs to train the model. An epoch is an iteration over the entire data provided, as defined by steps_per_epoch. 
#Note that in conjunction with initial_epoch, epochs is to be understood as "final epoch". The model is not trained for a number of iterations given by epochs,
#but merely until the epoch of index epochs is reached.
#steps_per_epoch=100000/200=500
#validation_steps=10000/200=50
#nb_epoch = 100
# checkpoint
#filepath="./tiny-imagenet-200/weights.best.hdf5"
model.load_weights(filepath)
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

nb_epoch = 5
model.fit_generator(train_generator, epochs=nb_epoch, steps_per_epoch=500, validation_steps=50, validation_data=validation_generator, callbacks=callbacks_list)
# Out:
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/5
# 500/500 [==============================] - 367s 735ms/step - loss: 2.6410 - acc: 0.3840 - val_loss: 3.4401 - val_acc: 0.3090
#
# Epoch 00001: val_acc improved from -inf to 0.30900, saving model to drive/app/weights.best.hdf5
# Epoch 2/5
# 500/500 [==============================] - 351s 703ms/step - loss: 1.8523 - acc: 0.5285 - val_loss: 3.5655 - val_acc: 0.3129
#
# Epoch 00002: val_acc improved from 0.30900 to 0.31290, saving model to drive/app/weights.best.hdf5

# %%
# load data
val_data = pd.read_csv('./tiny-imagenet-200/val/val_annotations.txt', sep='\t', header=None, names=['File', 'Class', 'X', 'Y', 'H', 'W'])
val_data.drop(['X', 'Y', 'H', 'W'], axis=1, inplace=True)
# input image dimensions
img_rows, img_cols = 64, 64
batch_size=50
#val_data.head(10)
# Use Augmentaion parameters as required.
train_datagen = ImageDataGenerator(
    rescale= 1./255,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
    )

valid_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory( r'./tiny-imagenet-200/train/', target_size=(img_rows, img_cols), color_mode='rgb', 
                                                    batch_size=batch_size, class_mode='categorical', shuffle=True, seed=42)
validation_generator = valid_datagen.flow_from_dataframe(val_data, directory='./tiny-imagenet-200/val/images/', x_col='File', y_col='Class', target_size=(img_rows, img_cols),
                                                    color_mode='rgb', class_mode='categorical', batch_size=batch_size, shuffle=True, seed=42)
x_batch, y_batch = next(train_generator)
x_batch.shape
# Plot Generator images.  ** Re-run the cell to view different set of images.

fig = plt.figure(figsize=(14, 5))

for i in range(8):
    sub = fig.add_subplot(2, 4, i + 1)
    sub.imshow(x_batch[i,:,:], interpolation='nearest')
nb_classes = 200
#nb_epoch = 100
img_channels = 3
model = ResnetBuilder.build_resnet_50_pyramid((img_channels,img_rows,img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
#model.summary()

#model.fit_generator(train_generator, ep`ochs=nb_epoch, steps_per_epoch=200, validation_steps=200, validation_data=validation_generator
##steps_per_epoch=Integer. Total number of steps (batches of samples) to yield from generator before declaring one epoch finished and starting the next epoch. 
#It should typically be equal to ceil(num_samples / batch_size) Optional for Sequence: if unspecified, will use the len(generator) as a number of steps.
##validation_steps=Only relevant if validation_data is a generator. Total number of steps (batches of samples) to yield from validation_data generator before stopping at the end of every epoch. 
#It should typically be equal to the number of samples of your validation dataset divided by the batch size. Optional for Sequence: if unspecified, will use the len(validation_data) as a number of steps.
##epochs: Integer. Number of epochs to train the model. An epoch is an iteration over the entire data provided, as defined by steps_per_epoch. 
#Note that in conjunction with initial_epoch, epochs is to be understood as "final epoch". The model is not trained for a number of iterations given by epochs,
#but merely until the epoch of index epochs is reached.
#steps_per_epoch=100000/200=500
#validation_steps=10000/200=50
#nb_epoch = 100
# checkpoint
#filepath="./tiny-imagenet-200/weights.best.hdf5"
model.load_weights(filepath)
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

nb_epoch = 10
model.fit_generator(train_generator, epochs=nb_epoch, steps_per_epoch=500, validation_steps=50, validation_data=validation_generator, callbacks=callbacks_list)

# %%
# load data
val_data = pd.read_csv('./tiny-imagenet-200/val/val_annotations.txt', sep='\t', header=None, names=['File', 'Class', 'X', 'Y', 'H', 'W'])
val_data.drop(['X', 'Y', 'H', 'W'], axis=1, inplace=True)
# input image dimensions
img_rows, img_cols = 64, 64
batch_size=50
#val_data.head(10)
# Use Augmentaion parameters as required.
train_datagen = ImageDataGenerator(
    rescale= 1./255,
    zoom_range = 0.1,
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True
    )

valid_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory( r'./tiny-imagenet-200/train/', target_size=(img_rows, img_cols), color_mode='rgb', 
                                                    batch_size=batch_size, class_mode='categorical', shuffle=True, seed=42)
validation_generator = valid_datagen.flow_from_dataframe(val_data, directory='./tiny-imagenet-200/val/images/', x_col='File', y_col='Class', target_size=(img_rows, img_cols),
                                                    color_mode='rgb', class_mode='categorical', batch_size=batch_size, shuffle=True, seed=42)
x_batch, y_batch = next(train_generator)
x_batch.shape
# Plot Generator images.  ** Re-run the cell to view different set of images.

fig = plt.figure(figsize=(14, 5))

for i in range(8):
    sub = fig.add_subplot(2, 4, i + 1)
    sub.imshow(x_batch[i,:,:], interpolation='nearest')
nb_classes = 200
#nb_epoch = 100
img_channels = 3
model = ResnetBuilder.build_resnet_50_pyramid((img_channels,img_rows,img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
#model.summary()

#model.fit_generator(train_generator, ep`ochs=nb_epoch, steps_per_epoch=200, validation_steps=200, validation_data=validation_generator
##steps_per_epoch=Integer. Total number of steps (batches of samples) to yield from generator before declaring one epoch finished and starting the next epoch. 
#It should typically be equal to ceil(num_samples / batch_size) Optional for Sequence: if unspecified, will use the len(generator) as a number of steps.
##validation_steps=Only relevant if validation_data is a generator. Total number of steps (batches of samples) to yield from validation_data generator before stopping at the end of every epoch. 
#It should typically be equal to the number of samples of your validation dataset divided by the batch size. Optional for Sequence: if unspecified, will use the len(validation_data) as a number of steps.
##epochs: Integer. Number of epochs to train the model. An epoch is an iteration over the entire data provided, as defined by steps_per_epoch. 
#Note that in conjunction with initial_epoch, epochs is to be understood as "final epoch". The model is not trained for a number of iterations given by epochs,
#but merely until the epoch of index epochs is reached.
#steps_per_epoch=100000/200=500
#validation_steps=10000/200=50
#nb_epoch = 100
# checkpoint
#filepath="./tiny-imagenet-200/weights.best.hdf5"
model.load_weights(filepath)
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

nb_epoch = 15
model.fit_generator(train_generator, epochs=nb_epoch, steps_per_epoch=500, validation_steps=50, validation_data=validation_generator, callbacks=callbacks_list)
# Out:
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/15
# 500/500 [==============================] - 774s 2s/step - loss: 0.7215 - acc: 0.8568 - val_loss: 2.3576 - val_acc: 0.4976
#
# Epoch 00001: val_acc improved from -inf to 0.49760, saving model to drive/app/weights.best.hdf5
# Epoch 2/15
# 500/500 [==============================] - 763s 2s/step - loss: 0.7017 - acc: 0.8583 - val_loss: 2.3968 - val_acc: 0.4896
#
# Epoch 00002: val_acc did not improve from 0.49760
# Epoch 3/15
# 500/500 [==============================] - 760s 2s/step - loss: 0.6883 - acc: 0.8654 - val_loss: 2.3759 - val_acc: 0.4912
#
# Epoch 00003: val_acc did not improve from 0.49760
# Epoch 4/15
# 500/500 [==============================] - 759s 2s/step - loss: 0.6928 - acc: 0.8608 - val_loss: 2.4271 - val_acc: 0.4920
#
# Epoch 00004: val_acc did not improve from 0.49760
# Epoch 5/15
# 500/500 [==============================] - 760s 2s/step - loss: 0.5081 - acc: 0.9124 - val_loss: 2.2974 - val_acc: 0.5068
#
# Epoch 00005: val_acc improved from 0.49760 to 0.50680, saving model to drive/app/weights.best.hdf5
# Epoch 6/15
# 500/500 [==============================] - 759s 2s/step - loss: 0.5916 - acc: 0.8914 - val_loss: 2.4779 - val_acc: 0.4780
#
# Epoch 00006: val_acc did not improve from 0.50680
# Epoch 7/15
# 500/500 [==============================] - 759s 2s/step - loss: 0.6359 - acc: 0.8772 - val_loss: 2.5008 - val_acc: 0.4840
#
# Epoch 00007: val_acc did not improve from 0.50680
# Epoch 8/15
# 500/500 [==============================] - 762s 2s/step - loss: 0.6630 - acc: 0.8644 - val_loss: 2.4495 - val_acc: 0.4844
#
# Epoch 00008: val_acc did not improve from 0.50680
# Epoch 9/15
# 500/500 [==============================] - 763s 2s/step - loss: 0.3895 - acc: 0.9436 - val_loss: 2.2446 - val_acc: 0.5364
#
# Epoch 00009: val_acc improved from 0.50680 to 0.53640, saving model to drive/app/weights.best.hdf5
# Epoch 10/15
# 500/500 [==============================] - 762s 2s/step - loss: 0.9026 - acc: 0.7706 - val_loss: 3.0745 - val_acc: 0.4112
#
# Epoch 00010: val_acc did not improve from 0.53640
# Epoch 11/15
# 500/500 [==============================] - 763s 2s/step - loss: 0.9394 - acc: 0.7584 - val_loss: 2.6074 - val_acc: 0.4560
#
# Epoch 00011: val_acc did not improve from 0.53640
# Epoch 12/15
# 500/500 [==============================] - 763s 2s/step - loss: 0.9658 - acc: 0.7488 - val_loss: 2.6472 - val_acc: 0.4708
#
# Epoch 00012: val_acc did not improve from 0.53640
# Epoch 13/15
# 500/500 [==============================] - 763s 2s/step - loss: 0.6411 - acc: 0.8473 - val_loss: 2.1984 - val_acc: 0.5320
#
# Epoch 00013: val_acc did not improve from 0.53640
# Epoch 14/15
# 500/500 [==============================] - 763s 2s/step - loss: 0.6950 - acc: 0.8320 - val_loss: 2.4079 - val_acc: 0.5192
#
# Epoch 00014: val_acc did not improve from 0.53640
# Epoch 15/15
# 500/500 [==============================] - 761s 2s/step - loss: 0.7420 - acc: 0.8159 - val_loss: 2.3559 - val_acc: 0.5148
#
# Epoch 00015: val_acc did not improve from 0.53640

# %%
filepath="drive/app/weights.best.hdf5"
print("Saved the model to disk")
from google.colab import files

files.download(filepath)
# Out:
# Saved the model to disk

# %%
# load data
val_data = pd.read_csv('./tiny-imagenet-200/val/val_annotations.txt', sep='\t', header=None, names=['File', 'Class', 'X', 'Y', 'H', 'W'])
val_data.drop(['X', 'Y', 'H', 'W'], axis=1, inplace=True)
# input image dimensions
img_rows, img_cols = 64, 64
batch_size=50
#val_data.head(10)
# Use Augmentaion parameters as required.
train_datagen = ImageDataGenerator(
    rescale= 1./255,
    zoom_range = 0.2,
    width_shift_range=0.15,
    height_shift_range=0.15,
    horizontal_flip=True
    )

valid_datagen = ImageDataGenerator(rescale=1./255)
train_generator = train_datagen.flow_from_directory( r'./tiny-imagenet-200/train/', target_size=(img_rows, img_cols), color_mode='rgb', 
                                                    batch_size=batch_size, class_mode='categorical', shuffle=True, seed=42)
validation_generator = valid_datagen.flow_from_dataframe(val_data, directory='./tiny-imagenet-200/val/images/', x_col='File', y_col='Class', target_size=(img_rows, img_cols),
                                                    color_mode='rgb', class_mode='categorical', batch_size=batch_size, shuffle=True, seed=42)
x_batch, y_batch = next(train_generator)
x_batch.shape
# Plot Generator images.  ** Re-run the cell to view different set of images.

fig = plt.figure(figsize=(14, 5))

for i in range(8):
    sub = fig.add_subplot(2, 4, i + 1)
    sub.imshow(x_batch[i,:,:], interpolation='nearest')
nb_classes = 200
#nb_epoch = 100
img_channels = 3
model = ResnetBuilder.build_resnet_50_pyramid((img_channels,img_rows,img_cols), nb_classes)
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])
#model.summary()

#model.fit_generator(train_generator, ep`ochs=nb_epoch, steps_per_epoch=200, validation_steps=200, validation_data=validation_generator
##steps_per_epoch=Integer. Total number of steps (batches of samples) to yield from generator before declaring one epoch finished and starting the next epoch. 
#It should typically be equal to ceil(num_samples / batch_size) Optional for Sequence: if unspecified, will use the len(generator) as a number of steps.
##validation_steps=Only relevant if validation_data is a generator. Total number of steps (batches of samples) to yield from validation_data generator before stopping at the end of every epoch. 
#It should typically be equal to the number of samples of your validation dataset divided by the batch size. Optional for Sequence: if unspecified, will use the len(validation_data) as a number of steps.
##epochs: Integer. Number of epochs to train the model. An epoch is an iteration over the entire data provided, as defined by steps_per_epoch. 
#Note that in conjunction with initial_epoch, epochs is to be understood as "final epoch". The model is not trained for a number of iterations given by epochs,
#but merely until the epoch of index epochs is reached.
#steps_per_epoch=100000/200=500
#validation_steps=10000/200=50
#nb_epoch = 100
# checkpoint
#filepath="./tiny-imagenet-200/weights.best.hdf5"
model.load_weights(filepath)
checkpoint = ModelCheckpoint(filepath, monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

nb_epoch = 15
model.fit_generator(train_generator, epochs=nb_epoch, steps_per_epoch=500, validation_steps=50, validation_data=validation_generator, callbacks=callbacks_list)
# Out:
# Found 100000 images belonging to 200 classes.
# Found 10000 images belonging to 200 classes.
# Epoch 1/15
# 500/500 [==============================] - 769s 2s/step - loss: 0.4959 - acc: 0.9103 - val_loss: 2.3171 - val_acc: 0.5176
#
# Epoch 00001: val_acc improved from -inf to 0.51760, saving model to drive/app/weights.best.hdf5
# Epoch 2/15
# 500/500 [==============================] - 760s 2s/step - loss: 0.5118 - acc: 0.9064 - val_loss: 2.6342 - val_acc: 0.4680
#
# Epoch 00002: val_acc did not improve from 0.51760
# Epoch 3/15
# 500/500 [==============================] - 761s 2s/step - loss: 0.5206 - acc: 0.9011 - val_loss: 2.4425 - val_acc: 0.5012
#
# Epoch 00003: val_acc did not improve from 0.51760
# Epoch 4/15
# 500/500 [==============================] - 760s 2s/step - loss: 0.5287 - acc: 0.8986 - val_loss: 2.6083 - val_acc: 0.4724
#
# Epoch 00004: val_acc did not improve from 0.51760
# Epoch 5/15
# 500/500 [==============================] - 762s 2s/step - loss: 0.3894 - acc: 0.9372 - val_loss: 2.5623 - val_acc: 0.4800
#
# Epoch 00005: val_acc did not improve from 0.51760
# Epoch 6/15
# 500/500 [==============================] - 761s 2s/step - loss: 0.4398 - acc: 0.9232 - val_loss: 2.6079 - val_acc: 0.4824
#
# Epoch 00006: val_acc did not improve from 0.51760
# Epoch 7/15
# 500/500 [==============================] - 760s 2s/step - loss: 0.4772 - acc: 0.9112 - val_loss: 2.5583 - val_acc: 0.4900
#
# Epoch 00007: val_acc did not improve from 0.51760
# Epoch 8/15
# 500/500 [==============================] - 761s 2s/step - loss: 0.4965 - acc: 0.9033 - val_loss: 2.5566 - val_acc: 0.5028
#
# Epoch 00008: val_acc did not improve from 0.51760
# Epoch 9/15
# 500/500 [==============================] - 759s 2s/step - loss: 0.3009 - acc: 0.9570 - val_loss: 2.5088 - val_acc: 0.5268
#
# Epoch 00009: val_acc improved from 0.51760 to 0.52680, saving model to drive/app/weights.best.hdf5
# Epoch 10/15
# 500/500 [==============================] - 759s 2s/step - loss: 0.8522 - acc: 0.7744 - val_loss: 2.7880 - val_acc: 0.4676
#
# Epoch 00010: val_acc did not improve from 0.52680
# Epoch 11/15
# 500/500 [==============================] - 756s 2s/step - loss: 0.8872 - acc: 0.7635 - val_loss: 2.8242 - val_acc: 0.4548
#
# Epoch 00011: val_acc did not improve from 0.52680
# Epoch 12/15
# 500/500 [==============================] - 764s 2s/step - loss: 0.9023 - acc: 0.7619 - val_loss: 2.6206 - val_acc: 0.4788
#
# Epoch 00012: val_acc did not improve from 0.52680
# Epoch 13/15
# 500/500 [==============================] - 760s 2s/step - loss: 0.5935 - acc: 0.8551 - val_loss: 2.3585 - val_acc: 0.5316
#
# Epoch 00013: val_acc improved from 0.52680 to 0.53160, saving model to drive/app/weights.best.hdf5
# Epoch 14/15
# 500/500 [==============================] - 762s 2s/step - loss: 0.6403 - acc: 0.8427 - val_loss: 2.6422 - val_acc: 0.4888
#
# Epoch 00014: val_acc did not improve from 0.53160
# Epoch 15/15
# 500/500 [==============================] - 762s 2s/step - loss: 0.6913 - acc: 0.8225 - val_loss: 2.5582 - val_acc: 0.5032
#
# Epoch 00015: val_acc did not improve from 0.53160

# %%
#filepath="drive/app/weights.best.hdf5"
print("Saved the model to disk")
from google.colab import files

files.download(filepath)
# Out:
# Saved the model to disk
